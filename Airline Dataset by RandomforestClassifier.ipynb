# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
o = pd.read_csv("C:\\Users\\SMART COMPUTERS\\Downloads\\Airline Dataset.csv")
o
# Out:
#        Passenger ID  First Name  Last Name  Gender   Age Nationality  \
# 0           10856.0      Edithe     Leggis  Female  62.0       Japan
# 1               NaN         NaN        NaN     NaN   NaN         NaN
# 2               NaN         NaN        NaN     NaN   NaN         NaN
# 3               NaN         NaN        NaN     NaN   NaN         NaN
# 4           82072.0         Bay    Pencost    Male  21.0       China
# ...             ...         ...        ...     ...   ...         ...
# 98614       58454.0      Gareth    Mugford    Male  85.0       China
# 98615       22028.0       Kasey   Benedict  Female  19.0      Russia
# 98616       61732.0      Darrin     Lucken    Male  65.0   Indonesia
# 98617       19819.0       Gayle  Lievesley  Female  34.0       China
# 98618       14485.0  Wilhelmine     Touret  Female  10.0      Poland
#
#                       Airport Name Airport Country Code        Country Name  \
# ...

# %%
df=o.dropna()
df
# Out:
#        Passenger ID  First Name  Last Name  Gender   Age  Nationality  \
# 0           10856.0      Edithe     Leggis  Female  62.0        Japan
# 4           82072.0         Bay    Pencost    Male  21.0        China
# 5           39630.0        Lora    Durbann  Female  55.0       Brazil
# 6           11940.0        Rand       Bram    Male  73.0  Ivory Coast
# 7           26470.0    Perceval   Dallosso    Male  36.0      Vietnam
# ...             ...         ...        ...     ...   ...          ...
# 98614       58454.0      Gareth    Mugford    Male  85.0        China
# 98615       22028.0       Kasey   Benedict  Female  19.0       Russia
# 98616       61732.0      Darrin     Lucken    Male  65.0    Indonesia
# 98617       19819.0       Gayle  Lievesley  Female  34.0        China
# 98618       14485.0  Wilhelmine     Touret  Female  10.0       Poland
#
#                             Airport Name Airport Country Code  \
# 0                       Coldfoot Airport                   US
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df.isna().sum()
# Out:
# Passenger ID            0
# First Name              0
# Last Name               0
# Gender                  0
# Age                     0
# Nationality             0
# Airport Name            0
# Airport Country Code    0
# Country Name            0
# Airport Continent       0
# Continents              0
# Departure Date          0
# Arrival Airport         0
# Pilot Name              0
# Flight Status           0
# dtype: int64

# %%
p_1=['Gender','Nationality','Airport Name',
 'Airport Country Code','Airport Continent',
   'Continents','Departure Date','Arrival Airport','Pilot Name','Flight Status']

# %%
df['Continents'].value_counts()
# Out:
# North America    32031
# Asia             18637
# Oceania          13866
# Europe           12334
# Africa           11030
# South America    10718
# Name: Continents, dtype: int64

# %%
le = LabelEncoder()
for i in p_1 :
    df[i] = le.fit_transform(df[i])
# Out:
# C:\Users\SMART COMPUTERS\AppData\Local\Temp\ipykernel_1052\1531665252.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i] = le.fit_transform(df[i])
# C:\Users\SMART COMPUTERS\AppData\Local\Temp\ipykernel_1052\1531665252.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i] = le.fit_transform(df[i])
# C:\Users\SMART COMPUTERS\AppData\Local\Temp\ipykernel_1052\1531665252.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
x=df[['Gender','Nationality','Airport Name',
 'Airport Country Code','Airport Continent',
   'Continents','Departure Date','Arrival Airport','Pilot Name','Flight Status','Passenger ID']]

# %%
y=df['Flight Status']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, 
                                                    test_size = 0.2)

# %%
model = RandomForestClassifier()
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
pre=model.predict(x_test) #On Time=0,Cancelled=1,Delayed=2
pre
# Out:
# array([0, 0, 0, ..., 1, 0, 2])

# %%
pd.series(model.features_importances_,index=Airline:features_names).sort_values(ascending=False)

# %%
 x_test
# Out:
#        Gender  Nationality  Airport Name  Airport Country Code  \
# 52101       0           43           984                    18
# 7308        0           96          3654                    11
# 32966       1           43          9059                   125
# 28707       0          168          7844                   168
# 34992       1           71          2884                    34
# ...       ...          ...           ...                   ...
# 29192       1          209          1199                   219
# 2506        1          168          3648                    57
# 78464       0          161          5794                   219
# 35078       1           37          5825                   219
# 42474       0           54          1662                    63
#
#        Airport Continent  Continents  Departure Date  Arrival Airport  \
# 52101                  0           0             329             8351
# ...

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %%
model.predict([[1,2,45,67,5,4,3,5,6,6,7]])
# Out:
# C:\ProgramData\anaconda5\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([2])
